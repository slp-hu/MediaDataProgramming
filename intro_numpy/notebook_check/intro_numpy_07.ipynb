# %% [markdown]
# <a href="https://colab.research.google.com/github/sp-au-mu-nl/MediaDataProgramming/blob/main/intro_numpy/notebook_check/intro_numpy_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 準備（最初に実行してください）
# !wget -q -O mdpcheck.py https://raw.githubusercontent.com/slp-hu/MediaDataProgramming/main/intro_numpy/check/mdpcheck.py
from mdpcheck import setup
check = setup("07")

# %% [markdown]
# # 配列作成関数

# %%
import numpy as np

# %% [markdown]
# numpy には、乱数の行列など、一般に使用される行列の作成に役立つ関数が多数あります。

# %%
x = np.random.rand(2,2)
x

# %% [markdown]
# 一様分布の乱数の 2行2列の行列が作成されました。
#
# 乱数の5行5列の行列である x という行列を作成しましょう。

# %%
x = np.random.rand(5,5)
x

# %% [markdown]
# rand を利用して 5行1列の配列を作成して x という変数に代入しましょう。

# %%
x = np.random.rand(5,1)
x

# %% [markdown]
# zeros を利用して 6 行 3 列の、すべてゼロの行列を作成して、x という変数に代入しましょう。

# %%
x = np.zeros((6,3),np.int32)
x

# %% [markdown]
# tile を使うと、同じ配列を繰り返し並べた行列を作れます。
# 繰り返す回数は (行方向, 列方向) の順に指定します。

# %%
np.tile(np.array([1,2,3]), (2,1))

# %% [markdown]
# 1 行 3 列の配列が、縦に 2 回並びました。
#
# `np.array([1,2])` を縦に 3 回、横に 2 回並べた行列を作成して、x という変数に代入しましょう。

# %%
check("q1")

# %% [markdown]
# shape 属性を使うと、既存の行列と同じサイズの行列を簡単に作れます。

# %%
y = np.random.rand(*x.shape)
y.shape

# %% [markdown]
# \* は、タプルを数字の列に展開します。
